# %% [markdown]
# # Place recognition pipeline using 3D Lidar scans and M2DP
#
# ### Import

# %%
import os
import glob
import numpy as np

from read_vel_hits import VelodyneSyncReader
from M2DP.m2dp import M2DP

# %% [markdown]
# #### 2. Init paths and reader

# %%
session_velodyne_sync_dir = (
    "/Users/felix/Projects/amr_hw3/velodyne_data/2012-01-08/velodyne_sync"
)

save_npz_path = (
    "/Users/felix/Projects/amr_hw3/velodyne_data/2012-01-08/"
    "m2dp_descriptors_2012-01-08.npz"
)

reader = VelodyneSyncReader()

# %% [markdown]
# ### get all utime.bin files

# %%
bin_files = sorted(
    glob.glob(os.path.join(session_velodyne_sync_dir, "*.bin"))
)

print(f"Found {len(bin_files)} velodyne scans.")
# Out:
# Found 28127 velodyne scans.

# %% [markdown]
# ### calculate descriptors

# %% [markdown]
# #### build M2DP instance to run algorithm

# %%
m2dp = M2DP()

# %%
utimes_list = []
desc_list = []

for idx, fp in enumerate(bin_files):
    utime = int(os.path.splitext(os.path.basename(fp))[0])

    points = reader.read(fp)        # (N, 3)
    descriptor, _ = m2dp.runM2DP(points)

    descriptor = np.asarray(descriptor, dtype=np.float32).ravel()

    utimes_list.append(utime)
    desc_list.append(descriptor)

    if idx % 200 == 0:
        print(
            f"[{idx}/{len(bin_files)}] "
            f"utime={utime}, points={points.shape[0]}, "
            f"desc_dim={descriptor.shape[0]}"
        )
# Out:
# time used for calculating a point cloud with M2DP: 0.070 seconds
# [0/28127] utime=1326030975726043, points=39490, desc_dim=192
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.131 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.131 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.116 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.083 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.067 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.080 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.075 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.094 seconds
# time used for calculating a point cloud with M2DP: 0.082 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.116 seconds
# time used for calculating a point cloud with M2DP: 0.094 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.077 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.081 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.077 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.094 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.119 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.080 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.082 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.094 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.124 seconds
# time used for calculating a point cloud with M2DP: 0.166 seconds
# time used for calculating a point cloud with M2DP: 0.080 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# [200/28127] utime=1326031015926924, points=31005, desc_dim=192
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.073 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.081 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.078 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.075 seconds
# time used for calculating a point cloud with M2DP: 0.082 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.065 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.082 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.082 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.080 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.083 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.072 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.078 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.083 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.074 seconds
# time used for calculating a point cloud with M2DP: 0.078 seconds
# time used for calculating a point cloud with M2DP: 0.079 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.094 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.080 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.187 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.140 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.084 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.151 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.088 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.093 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.121 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.086 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.122 seconds
# time used for calculating a point cloud with M2DP: 0.127 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.124 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.125 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.297 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.097 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.132 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# [400/28127] utime=1326031055927812, points=40350, desc_dim=192
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.119 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.123 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.101 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.092 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.082 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.085 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.119 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.116 seconds
# time used for calculating a point cloud with M2DP: 0.108 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.090 seconds
# time used for calculating a point cloud with M2DP: 0.294 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.091 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.112 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.098 seconds
# time used for calculating a point cloud with M2DP: 0.125 seconds
# time used for calculating a point cloud with M2DP: 0.100 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.087 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.089 seconds
# time used for calculating a point cloud with M2DP: 0.126 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.113 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.122 seconds
# time used for calculating a point cloud with M2DP: 0.103 seconds
# time used for calculating a point cloud with M2DP: 0.124 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.111 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.124 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.104 seconds
# time used for calculating a point cloud with M2DP: 0.109 seconds
# time used for calculating a point cloud with M2DP: 0.095 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.105 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.107 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.096 seconds
# time used for calculating a point cloud with M2DP: 0.126 seconds
# time used for calculating a point cloud with M2DP: 0.124 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.110 seconds
# time used for calculating a point cloud with M2DP: 0.129 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.102 seconds
# time used for calculating a point cloud with M2DP: 0.118 seconds
# time used for calculating a point cloud with M2DP: 0.106 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.099 seconds
# time used for calculating a point cloud with M2DP: 0.117 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.131 seconds
# time used for calculating a point cloud with M2DP: 0.129 seconds
# time used for calculating a point cloud with M2DP: 0.126 seconds
# time used for calculating a point cloud with M2DP: 0.139 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.128 seconds
# time used for calculating a point cloud with M2DP: 0.129 seconds
# time used for calculating a point cloud with M2DP: 0.125 seconds
# time used for calculating a point cloud with M2DP: 0.124 seconds
# time used for calculating a point cloud with M2DP: 0.125 seconds
# time used for calculating a point cloud with M2DP: 0.130 seconds
# time used for calculating a point cloud with M2DP: 0.133 seconds
# time used for calculating a point cloud with M2DP: 0.120 seconds
# time used for calculating a point cloud with M2DP: 0.151 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.125 seconds
# time used for calculating a point cloud with M2DP: 0.132 seconds
# time used for calculating a point cloud with M2DP: 0.119 seconds
# time used for calculating a point cloud with M2DP: 0.119 seconds
# time used for calculating a point cloud with M2DP: 0.135 seconds
# time used for calculating a point cloud with M2DP: 0.128 seconds
# time used for calculating a point cloud with M2DP: 0.115 seconds
# time used for calculating a point cloud with M2DP: 0.133 seconds
# time used for calculating a point cloud with M2DP: 0.195 seconds
# time used for calculating a point cloud with M2DP: 0.125 seconds
# time used for calculating a point cloud with M2DP: 0.139 seconds
# time used for calculating a point cloud with M2DP: 0.137 seconds
# time used for calculating a point cloud with M2DP: 0.144 seconds
# time used for calculating a point cloud with M2DP: 0.132 seconds
# time used for calculating a point cloud with M2DP: 0.121 seconds
# time used for calculating a point cloud with M2DP: 0.145 seconds
# time used for calculating a point cloud with M2DP: 0.150 seconds
# time used for calculating a point cloud with M2DP: 0.137 seconds
# time used for calculating a point cloud with M2DP: 0.137 seconds
# time used for calculating a point cloud with M2DP: 0.137 seconds
# time used for calculating a point cloud with M2DP: 0.145 seconds
# time used for calculating a point cloud with M2DP: 0.142 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.139 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.137 seconds
# time used for calculating a point cloud with M2DP: 0.129 seconds
# time used for calculating a point cloud with M2DP: 0.132 seconds
# time used for calculating a point cloud with M2DP: 0.135 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.143 seconds
# time used for calculating a point cloud with M2DP: 0.133 seconds
# time used for calculating a point cloud with M2DP: 0.142 seconds
# time used for calculating a point cloud with M2DP: 0.149 seconds
# time used for calculating a point cloud with M2DP: 0.131 seconds
# time used for calculating a point cloud with M2DP: 0.126 seconds
# time used for calculating a point cloud with M2DP: 0.142 seconds
# time used for calculating a point cloud with M2DP: 0.140 seconds
# time used for calculating a point cloud with M2DP: 0.147 seconds
# time used for calculating a point cloud with M2DP: 0.133 seconds
# time used for calculating a point cloud with M2DP: 0.145 seconds
# time used for calculating a point cloud with M2DP: 0.145 seconds
# time used for calculating a point cloud with M2DP: 0.147 seconds
# time used for calculating a point cloud with M2DP: 0.146 seconds
# time used for calculating a point cloud with M2DP: 0.146 seconds
# time used for calculating a point cloud with M2DP: 0.128 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.157 seconds
# time used for calculating a point cloud with M2DP: 0.141 seconds
# time used for calculating a point cloud with M2DP: 0.162 seconds
# time used for calculating a point cloud with M2DP: 0.144 seconds
# time used for calculating a point cloud with M2DP: 0.148 seconds
# time used for calculating a point cloud with M2DP: 0.140 seconds
# time used for calculating a point cloud with M2DP: 0.155 seconds
# time used for calculating a point cloud with M2DP: 0.170 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.150 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.129 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.146 seconds
# time used for calculating a point cloud with M2DP: 0.144 seconds
# time used for calculating a point cloud with M2DP: 0.155 seconds
# time used for calculating a point cloud with M2DP: 0.161 seconds
# [600/28127] utime=1326031096128675, points=52886, desc_dim=192
# time used for calculating a point cloud with M2DP: 0.154 seconds
# time used for calculating a point cloud with M2DP: 0.161 seconds
# time used for calculating a point cloud with M2DP: 0.156 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.154 seconds
# time used for calculating a point cloud with M2DP: 0.145 seconds
# time used for calculating a point cloud with M2DP: 0.171 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.140 seconds
# time used for calculating a point cloud with M2DP: 0.194 seconds
# time used for calculating a point cloud with M2DP: 0.158 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.156 seconds
# time used for calculating a point cloud with M2DP: 0.146 seconds
# time used for calculating a point cloud with M2DP: 0.145 seconds
# time used for calculating a point cloud with M2DP: 0.151 seconds
# time used for calculating a point cloud with M2DP: 0.158 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.159 seconds
# time used for calculating a point cloud with M2DP: 0.163 seconds
# time used for calculating a point cloud with M2DP: 0.159 seconds
# time used for calculating a point cloud with M2DP: 0.139 seconds
# time used for calculating a point cloud with M2DP: 0.130 seconds
# time used for calculating a point cloud with M2DP: 0.134 seconds
# time used for calculating a point cloud with M2DP: 0.141 seconds
# time used for calculating a point cloud with M2DP: 0.136 seconds
# time used for calculating a point cloud with M2DP: 0.144 seconds
# time used for calculating a point cloud with M2DP: 0.147 seconds
# time used for calculating a point cloud with M2DP: 0.150 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.146 seconds
# time used for calculating a point cloud with M2DP: 0.131 seconds
# time used for calculating a point cloud with M2DP: 0.114 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.184 seconds
# time used for calculating a point cloud with M2DP: 0.264 seconds
# time used for calculating a point cloud with M2DP: 0.229 seconds
# time used for calculating a point cloud with M2DP: 0.135 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.149 seconds
# time used for calculating a point cloud with M2DP: 0.151 seconds
# time used for calculating a point cloud with M2DP: 0.135 seconds
# time used for calculating a point cloud with M2DP: 0.147 seconds
# time used for calculating a point cloud with M2DP: 0.181 seconds
# time used for calculating a point cloud with M2DP: 0.199 seconds
# time used for calculating a point cloud with M2DP: 0.169 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.161 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.153 seconds
# time used for calculating a point cloud with M2DP: 0.167 seconds
# time used for calculating a point cloud with M2DP: 0.152 seconds
# time used for calculating a point cloud with M2DP: 0.163 seconds
# time used for calculating a point cloud with M2DP: 0.140 seconds
# time used for calculating a point cloud with M2DP: 0.139 seconds
# time used for calculating a point cloud with M2DP: 0.173 seconds
# time used for calculating a point cloud with M2DP: 0.138 seconds
# time used for calculating a point cloud with M2DP: 0.139 seconds
# time used for calculating a point cloud with M2DP: 0.147 seconds
# time used for calculating a point cloud with M2DP: 0.126 seconds
# time used for calculating a point cloud with M2DP: 0.135 seconds
# time used for calculating a point cloud with M2DP: 0.155 seconds
# time used for calculating a point cloud with M2DP: 0.170 seconds
# time used for calculating a point cloud with M2DP: 0.132 seconds
# time used for calculating a point cloud with M2DP: 0.147 seconds
# time used for calculating a point cloud with M2DP: 0.156 seconds
# time used for calculating a point cloud with M2DP: 0.169 seconds
# time used for calculating a point cloud with M2DP: 0.158 seconds
# time used for calculating a point cloud with M2DP: 0.154 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 utime = int(os.path.splitext(os.path.basename(fp))[0])
#       7 points = reader.read(fp)        # (N, 3)
# ----> 8 descriptor, _ = m2dp.runM2DP(points)
#      10 descriptor = np.asarray(descriptor, dtype=np.float32).ravel()
#      12 utimes_list.append(utime)
#
# File ~/Projects/amr_hw3/M2DP/m2dp/M2DP.py:127, in M2DP.runM2DP(self, cloud)
#     125 maxRho=np.sqrt(rho2.max())
#     126 #main function, get the signature matrix A
# --> 127 A=self.GetSignatureMatrix(azimuthList, elevationList, cloud_pca, self.numT, self.numR, maxRho)
#     128 #run SVD on A and use [u0,v0] as the final output
#     129 u,s,v = np.linalg.svd(A)
#
# File ~/Projects/amr_hw3/M2DP/m2dp/M2DP.py:99, in M2DP.GetSignatureMatrix(self, azimuthList, elevationList, cloud_pca, numT, numR, maxRho)
#      96 pcy=cloud_pca@py.T
#      97 #pdata = np.array([pcx,pcy])
#      98 #represent data in polar coordinates
# ---> 99 rho,theta=self.cart2pol(pcx,pcy)
#     101 #main function, count points in bins
#     102 hist= np.histogram2d(theta.T,rho.T,[thetaList,rhoList])[0]
#
# File ~/Projects/amr_hw3/M2DP/m2dp/M2DP.py:58, in M2DP.cart2pol(self, x, y)
#      56 def cart2pol(self,x, y):
#      57     rho = np.sqrt(x**2 + y**2)
# ---> 58     phi = np.arctan2(y, x)
#      59     return(rho, phi)
#
# KeyboardInterrupt:

# %% [markdown]
# ### build descriptor matrix and save

# %%
utimes = np.asarray(utimes_list, dtype=np.int64)

D = desc_list[0].shape[0]
for i, d in enumerate(desc_list):
    if d.shape[0] != D:
        raise ValueError(
            f"Inconsistent descriptor dimension at index {i}: "
            f"expected {D}, got {d.shape[0]}"
        )

descriptors = np.vstack(desc_list).astype(np.float32)

np.savez_compressed(
    save_npz_path,
    utimes=utimes,
    descriptors=descriptors
)

print("Saved descriptors:")
print("  utimes:", utimes.shape)
print("  descriptors:", descriptors.shape)
print("  file:", save_npz_path)

# %% [markdown]
# #### check if it works - optional

# %%
data = np.load(save_npz_path)
utimes_loaded = data["utimes"]
descriptors_loaded = data["descriptors"]

print("Loaded:")
print("  utimes:", utimes_loaded[:5])
print("  descriptors shape:", descriptors_loaded.shape)

# %% [markdown]
# #### 3. Run M2DP algorithm

# %%
from M2DP.m2dp import M2DP

m2dp = M2DP()
descriptorVector, signatureMatrix = m2dp.runM2DP(PointCloudMatrix)

print("shape of descriptor vector: " + str(descriptorVector.shape))
print("shape of signature matrix: " + str(signatureMatrix.shape[0]) + " x " + str(signatureMatrix.shape[1]))
